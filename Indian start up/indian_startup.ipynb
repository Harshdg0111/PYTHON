# %%
import pandas as pd

# %%
df = pd.read_csv(r"c:\Users\hdg01\Downloads\startup_funding.csv")
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df[['Date dd/mm/yyyy']]
# Out:
#      Date dd/mm/yyyy
# 0         09/01/2020
# 1         13/01/2020
# 2         09/01/2020
# 3         02/01/2020
# 4         02/01/2020
# ...              ...
# 3039      29/01/2015
# 3040      29/01/2015
# 3041      30/01/2015
# 3042      30/01/2015
# 3043      31/01/2015
#
# [3044 rows x 1 columns]

# %%
df['Date dd/mm/yyyy'] = pd.to_datetime(df['Date dd/mm/yyyy'], format='%d/%m/%Y', errors='coerce')
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      2020-01-09                        BYJU’S               E-Tech
# 1      2      2020-01-13                        Shuttl       Transportation
# 2      3      2020-01-09                     Mamaearth           E-commerce
# 3      4      2020-01-02  https://www.wealthbucket.in/              FinTech
# 4      5      2020-01-02                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.dtypes
# Out:
# Sr No                         int64
# Date dd/mm/yyyy      datetime64[ns]
# Startup Name                 object
# Industry Vertical            object
# SubVertical                  object
# City  Location               object
# Investors Name               object
# InvestmentnType              object
# Amount in USD                object
# Remarks                      object
# dtype: object

# %%
df.rename(columns={'Date dd/mm/yyyy': 'Date','Startup Name':'Name','Industry Vertical':'Industry','SubVertical':'Market_Segment','City  Location':'Location','Investors Name':'Investors','InvestmentnType':'Investmentn_Type','Amount in USD':'Amount'}, inplace=True)
df
# Out:
#       Sr No       Date                          Name             Industry  \
# 0         1 2020-01-09                        BYJU’S               E-Tech
# 1         2 2020-01-13                        Shuttl       Transportation
# 2         3 2020-01-09                     Mamaearth           E-commerce
# 3         4 2020-01-02  https://www.wealthbucket.in/              FinTech
# 4         5 2020-01-02                        Fashor  Fashion and Apparel
# ...     ...        ...                           ...                  ...
# 3039   3040 2015-01-29                    Printvenue                  NaN
# 3040   3041 2015-01-29                      Graphene                  NaN
# 3041   3042 2015-01-30                Mad Street Den                  NaN
# 3042   3043 2015-01-30                     Simplotel                  NaN
# 3043   3044 2015-01-31              couponmachine.in                  NaN
#
#                              Market_Segment   Location  \
# ...

# %%
df = df.drop(columns='Sr No')

# %%
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3039 2015-01-29                    Printvenue                  NaN
# 3040 2015-01-29                      Graphene                  NaN
# 3041 2015-01-30                Mad Street Den                  NaN
# 3042 2015-01-30                     Simplotel                  NaN
# 3043 2015-01-31              couponmachine.in                  NaN
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df['Amount'] = df['Amount'].str.replace(',', '')
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3039 2015-01-29                    Printvenue                  NaN
# 3040 2015-01-29                      Graphene                  NaN
# 3041 2015-01-30                Mad Street Den                  NaN
# 3042 2015-01-30                     Simplotel                  NaN
# 3043 2015-01-31              couponmachine.in                  NaN
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df.shape
# Out:
# (3044, 9)

# %%
df = df.dropna(subset=['Amount'])
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com                  NaN
# 3039 2015-01-29                    Printvenue                  NaN
# 3040 2015-01-29                      Graphene                  NaN
# 3041 2015-01-30                Mad Street Den                  NaN
# 3043 2015-01-31              couponmachine.in                  NaN
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df['Amount'] = df['Amount'].str.replace(r'\\xc2\\xa0', '', regex=True)
# Out:
# C:\Users\hdg01\AppData\Local\Temp\ipykernel_16624\3634642339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount'] = df['Amount'].str.replace(r'\\xc2\\xa0', '', regex=True)
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com                  NaN
# ...

# %%
df = df.drop(columns=['Remarks'])

# %%
df.rename(columns={'Investmentn_Type':'Investment_Type'}, inplace=True)

# %%
df['Name'] = df['Name'].str.replace(r'\\xc2\\xa0', '', regex=True)

# %%
df['Industry'] = df['Industry'].str.replace(r'\\xc2\\xa0', '', regex=True)

# %%
df['Market_Segment'] = df['Market_Segment'].str.replace(r'\\xc2\\xa0', '', regex=True)

# %%
df['Location'] = df['Location'].str.replace(r'\\xc2\\xa0', '', regex=True)

# %%
df['Investors'] = df['Investors'].str.replace(r'\\xc2\\xa0', '', regex=True)

# %%
df['Investment_Type'] = df['Investment_Type'].str.replace(r'\\xc2\\xa0', '', regex=True)

# %%
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com                  NaN
# 3039 2015-01-29                    Printvenue                  NaN
# 3040 2015-01-29                      Graphene                  NaN
# 3041 2015-01-30                Mad Street Den                  NaN
# 3043 2015-01-31              couponmachine.in                  NaN
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df.isnull().sum()
# Out:
# Date                 7
# Name                 0
# Industry           131
# Market_Segment     658
# Location           135
# Investors           20
# Investment_Type      3
# Amount               0
# dtype: int64

# %%
df['Industry'].fillna('Unknown', inplace=True)
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com              Unknown
# 3039 2015-01-29                    Printvenue              Unknown
# 3040 2015-01-29                      Graphene              Unknown
# 3041 2015-01-30                Mad Street Den              Unknown
# 3043 2015-01-31              couponmachine.in              Unknown
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df['Market_Segment'].fillna('Unknown', inplace=True)
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com              Unknown
# 3039 2015-01-29                    Printvenue              Unknown
# 3040 2015-01-29                      Graphene              Unknown
# 3041 2015-01-30                Mad Street Den              Unknown
# 3043 2015-01-31              couponmachine.in              Unknown
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df['Location'].fillna('Unknown', inplace=True)
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com              Unknown
# 3039 2015-01-29                    Printvenue              Unknown
# 3040 2015-01-29                      Graphene              Unknown
# 3041 2015-01-30                Mad Street Den              Unknown
# 3043 2015-01-31              couponmachine.in              Unknown
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df['Investors'].fillna('Unknown', inplace=True)
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com              Unknown
# 3039 2015-01-29                    Printvenue              Unknown
# 3040 2015-01-29                      Graphene              Unknown
# 3041 2015-01-30                Mad Street Den              Unknown
# 3043 2015-01-31              couponmachine.in              Unknown
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df['Investment_Type'].fillna('Unknown', inplace=True)
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com              Unknown
# 3039 2015-01-29                    Printvenue              Unknown
# 3040 2015-01-29                      Graphene              Unknown
# 3041 2015-01-30                Mad Street Den              Unknown
# 3043 2015-01-31              couponmachine.in              Unknown
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df
# Out:
#            Date                          Name             Industry  \
# 0    2020-01-09                        BYJU’S               E-Tech
# 1    2020-01-13                        Shuttl       Transportation
# 2    2020-01-09                     Mamaearth           E-commerce
# 3    2020-01-02  https://www.wealthbucket.in/              FinTech
# 4    2020-01-02                        Fashor  Fashion and Apparel
# ...         ...                           ...                  ...
# 3038 2015-01-28                 Grabhouse.com              Unknown
# 3039 2015-01-29                    Printvenue              Unknown
# 3040 2015-01-29                      Graphene              Unknown
# 3041 2015-01-30                Mad Street Den              Unknown
# 3043 2015-01-31              couponmachine.in              Unknown
#
#                              Market_Segment   Location  \
# 0                                E-learning  Bengaluru
# ...

# %%
df = df.to_csv('StartUps_In_India.csv')
