# %%
import pandas as pd

# %%
df = pd.read_csv(r"c:\Users\hdg01\Downloads\Amazon Sale Report.csv\Amazon Sale Report.csv")
df
# Out:
# C:\Users\hdg01\AppData\Local\Temp\ipykernel_7068\1307083909.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"c:\Users\hdg01\Downloads\Amazon Sale Report.csv\Amazon Sale Report.csv")
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %% [markdown]
# ## Date

# %%
df[['Date']]
# Out:
#             Date
# 0       04-30-22
# 1       04-30-22
# 2       04-30-22
# 3       04-30-22
# 4       04-30-22
# ...          ...
# 128970  05-31-22
# 128971  05-31-22
# 128972  05-31-22
# 128973  05-31-22
# 128974  05-31-22
#
# [128975 rows x 1 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df
# Out:
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128970  128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  128974  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
df.dtypes
# Out:
# index                          int64
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfilment                    object
# Sales Channel                 object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int64
# currency                      object
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                             bool
# fulfilled-by                  object
# Unnamed: 22                   object
# dtype: object

# %% [markdown]
# ## Status

# %%
df[['Status']]
# Out:
#                               Status
# 0                          Cancelled
# 1       Shipped - Delivered to Buyer
# 2                            Shipped
# 3                          Cancelled
# 4                            Shipped
# ...                              ...
# 128970                       Shipped
# 128971                       Shipped
# 128972                       Shipped
# 128973                       Shipped
# 128974                       Shipped
#
# [128975 rows x 1 columns]

# %%
unique_status_values = df['Status'].unique()
unique_status_values
# Out:
# array(['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Shipped - Lost in Transit', 'Shipped - Out for Delivery',
#        'Shipped - Returning to Seller', 'Shipped - Picked Up', 'Pending',
#        'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping'],
#       dtype=object)

# %%
df.dtypes
# Out:
# index                          int64
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfilment                    object
# Sales Channel                 object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int64
# currency                      object
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                             bool
# fulfilled-by                  object
# Unnamed: 22                   object
# dtype: object

# %% [markdown]
# ## Fullfilment

# %%
unique_fulfilment_values = df['Fulfilment'].unique() 
unique_fulfilment_values
# Out:
# array(['Merchant', 'Amazon'], dtype=object)

# %%
df.rename(columns={'Fulfilment':'Fulfillment'},inplace=True)
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfillment Sales Channel  ship-service-level    Style              SKU  \
# 0    Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1    Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2      Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3    Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4      Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %% [markdown]
# ## sales channerl

# %%
pd.reset_option('display.width')

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status Fulfillment Sales Channel  ship-service-level    Style              SKU       Category  ... currency  Amount    ship-city  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled    Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S            Set  ...      INR  647.62       MUMBAI
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer    Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta  ...      INR  406.00    BENGALURU
# 2      2  404-0687676-7273146 2022-04-30                       Shipped      Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta  ...      INR  329.00  NAVI MUMBAI
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled    Merchant      Amazon.in           Standard    J0341       J0341-DR-L  Western Dress  ...      INR  753.33   PUDUCHERRY
# ...

# %%
df[['Sales Channel ']]
# Out:
#        Sales Channel
# 0           Amazon.in
# 1           Amazon.in
# 2           Amazon.in
# 3           Amazon.in
# 4           Amazon.in
# ...               ...
# 128970      Amazon.in
# 128971      Amazon.in
# 128972      Amazon.in
# 128973      Amazon.in
# 128974      Amazon.in
#
# [128975 rows x 1 columns]

# %%
df.rename(columns={'Sales Channel ':'Sales_Channel'},inplace=True)
df.head()
# Out:
#    index             Order ID       Date                        Status Fulfillment Sales_Channel ship-service-level    Style              SKU       Category  ... currency  Amount    ship-city  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled    Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S            Set  ...      INR  647.62       MUMBAI
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer    Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta  ...      INR  406.00    BENGALURU
# 2      2  404-0687676-7273146 2022-04-30                       Shipped      Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta  ...      INR  329.00  NAVI MUMBAI
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled    Merchant     Amazon.in           Standard    J0341       J0341-DR-L  Western Dress  ...      INR  753.33   PUDUCHERRY
# ...

# %%
unique_Sales_Channel_values = df['Sales_Channel'].unique() 
unique_Sales_Channel_values
# Out:
# array(['Amazon.in', 'Non-Amazon'], dtype=object)

# %%
df.dtypes
# Out:
# index                          int64
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfillment                   object
# Sales_Channel                 object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int64
# currency                      object
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                             bool
# fulfilled-by                  object
# Unnamed: 22                   object
# dtype: object

# %% [markdown]
# ## ship-service-level

# %%
df[['ship-service-level']]
# Out:
#        ship-service-level
# 0                Standard
# 1                Standard
# 2               Expedited
# 3                Standard
# 4               Expedited
# ...                   ...
# 128970          Expedited
# 128971          Expedited
# 128972          Expedited
# 128973          Expedited
# 128974          Expedited
#
# [128975 rows x 1 columns]

# %%
df.rename(columns={'ship-service-level':'Ship_Service_Level'},inplace=True)
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfillment Sales_Channel Ship_Service_Level    Style              SKU  \
# 0    Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1    Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2      Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3    Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4      Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
unique_Ship_Service_Level_values = df['Ship_Service_Level'].unique() 
unique_Ship_Service_Level_values
# Out:
# array(['Standard', 'Expedited'], dtype=object)

# %% [markdown]
# ## Style

# %%
df[['Style']]
# Out:
#           Style
# 0        SET389
# 1       JNE3781
# 2       JNE3371
# 3         J0341
# 4       JNE3671
# ...         ...
# 128970  JNE3697
# 128971   SET401
# 128972    J0157
# 128973    J0012
# 128974    J0003
#
# [128975 rows x 1 columns]

# %%
unique_Style_Level_values = df['Style'].unique() 
unique_Style_Level_values
# Out:
# array(['SET389', 'JNE3781', 'JNE3371', ..., 'SET066', 'J0286', 'SET045'],
#       dtype=object)

# %%
unique_Style_Level_values = df['Style'].nunique() 
unique_Style_Level_values
# Out:
# 1377

# %%
df.rename(columns={'Style':'Style_Id'},inplace=True)
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfillment Sales_Channel Ship_Service_Level Style_Id              SKU  \
# 0    Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1    Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2      Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3    Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4      Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %% [markdown]
# ## sku / product_id

# %%
df[['SKU']]
# Out:
#                     SKU
# 0        SET389-KR-NP-S
# 1       JNE3781-KR-XXXL
# 2         JNE3371-KR-XL
# 3            J0341-DR-L
# 4       JNE3671-TU-XXXL
# ...                 ...
# 128970    JNE3697-KR-XL
# 128971   SET401-KR-NP-M
# 128972     J0157-DR-XXL
# 128973     J0012-SKD-XS
# 128974      J0003-SET-S
#
# [128975 rows x 1 columns]

# %%
unique_SKU_values = df['SKU'].nunique() 
unique_SKU_values
# Out:
# 7195

# %%
df.rename(columns={'SKU':'Product_Id'},inplace=True)
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfillment Sales_Channel Ship_Service_Level Style_Id       Product_Id  \
# 0    Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1    Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2      Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3    Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4      Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.dtypes
# Out:
# index                          int64
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfillment                   object
# Sales_Channel                 object
# Ship_Service_Level            object
# Style_Id                      object
# Product_Id                    object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int64
# currency                      object
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                             bool
# fulfilled-by                  object
# Unnamed: 22                   object
# dtype: object

# %%
df[['Category']]
# Out:
#              Category
# 0                 Set
# 1               kurta
# 2               kurta
# 3       Western Dress
# 4                 Top
# ...               ...
# 128970          kurta
# 128971            Set
# 128972  Western Dress
# 128973            Set
# 128974            Set
#
# [128975 rows x 1 columns]

# %%
unique_SKU_values = df['Category'].unique() 
unique_SKU_values
# Out:
# array(['Set', 'kurta', 'Western Dress', 'Top', 'Ethnic Dress', 'Bottom',
#        'Saree', 'Blouse', 'Dupatta'], dtype=object)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfillment Sales_Channel Ship_Service_Level Style_Id       Product_Id  \
# 0    Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1    Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2      Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3    Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4      Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category Size        ASIN Courier Status  Qty currency  Amount  \
# ...

# %% [markdown]
# ## Courier Status

# %%
df[['Courier Status']]
# Out:
#        Courier Status
# 0                 NaN
# 1             Shipped
# 2             Shipped
# 3                 NaN
# 4             Shipped
# ...               ...
# 128970        Shipped
# 128971        Shipped
# 128972        Shipped
# 128973        Shipped
# 128974        Shipped
#
# [128975 rows x 1 columns]

# %%
unique_SKU_values = df['Courier Status'].unique() 
unique_SKU_values
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfillment               0
# Sales_Channel             0
# Ship_Service_Level        0
# Style_Id                  0
# Product_Id                0
# Category                  0
# Size                      0
# ASIN                      0
# Courier_Status            0
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.rename(columns={'Courier Status':'Courier_Status'},inplace=True)
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfillment Sales_Channel Ship_Service_Level Style_Id       Product_Id  \
# 0    Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1    Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2      Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3    Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4      Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category Size        ASIN Courier_Status  Qty currency  Amount  \
# ...

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfillment Sales_Channel Ship_Service_Level Style_Id       Product_Id  \
# 0    Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1    Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2      Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3    Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4      Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category Size        ASIN Courier_Status  Qty currency  Amount  \
# ...

# %% [markdown]
# ## currency

# %%
df[['currency']]
# Out:
#        currency
# 0           INR
# 1           INR
# 2           INR
# 3           INR
# 4           INR
# ...         ...
# 128970      INR
# 128971      INR
# 128972      INR
# 128973      INR
# 128974      INR
#
# [128975 rows x 1 columns]

# %%
unique_SKU_values = df['currency'].unique() 
unique_SKU_values
# Out:
# array(['INR', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfillment               0
# Sales_Channel             0
# Ship_Service_Level        0
# Style_Id                  0
# Product_Id                0
# Category                  0
# Size                      0
# ASIN                      0
# Courier_Status            0
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.shape
# Out:
# (128975, 24)

# %% [markdown]
# ## amount

# %%
df[['Amount']]
# Out:
#          Amount
# 0        647.62
# 1        406.00
# 2        329.00
# 3        753.33
# 4        574.00
# ...         ...
# 128970   517.00
# 128971   999.00
# 128972   690.00
# 128973  1199.00
# 128974   696.00
#
# [128975 rows x 1 columns]

# %%
unique_SKU_values = df['Amount'].nunique() 
unique_SKU_values
# Out:
# 1410

# %%
df.head(200)
# Out:
#      index             Order ID       Date                        Status  \
# 0        0  405-8078784-5731545 2022-04-30                     Cancelled
# 1        1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2        2  404-0687676-7273146 2022-04-30                       Shipped
# 3        3  403-9615377-8133951 2022-04-30                     Cancelled
# 4        4  407-1069790-7240320 2022-04-30                       Shipped
# ..     ...                  ...        ...                           ...
# 195    195  405-3036350-8089120 2022-04-30                       Shipped
# 196    196  404-6680046-0839536 2022-04-30  Shipped - Delivered to Buyer
# 197    197  406-2966654-4672325 2022-04-30                       Shipped
# 198    198  403-4845285-4565113 2022-04-30                       Shipped
# 199    199  171-4496851-5319548 2022-04-30                       Shipped
#
#     Fulfillment Sales_Channel Ship_Service_Level  Style_Id       Product_Id  \
# ...

# %% [markdown]
# ## ship country

# %%
df = df.dropna(subset=['ship-country'])

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfillment               0
# Sales_Channel             0
# Ship_Service_Level        0
# Style_Id                  0
# Product_Id                0
# Category                  0
# Size                      0
# ASIN                      0
# Courier_Status            0
# Qty                       0
# currency               7793
# Amount                 7793
# ship-city                 0
# ship-state                0
# ship-postal-code          0
# ship-country              0
# promotion-ids         49145
# B2B                       0
# fulfilled-by          89678
# Unnamed: 22           49037
# dtype: int64

# %%
df.shape
# Out:
# (128942, 24)
